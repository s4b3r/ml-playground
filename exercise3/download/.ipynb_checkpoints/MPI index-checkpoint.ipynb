# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import plotly.plotly as py
import plotly.tools as tls

# %%
tls.set_credentials_file(username='sab3r', api_key='HKmFy9ViLHOI97bG17Hq')
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

# %%
data = pd.read_csv("MPI.csv", sep=';', decimal=',')

# %%
data.isnull().sum()
# Out:
# Country                                              0
# Year_survey                                          0
# Index                                                0
# Headcount_(%)                                        0
# Intensity_of_deprivation                             0
# Number_of_poor_(year_of_survey)                      0
# Number_of_poor_2016                                  0
# Population_vulnerable_to_multidimensional_poverty    0
# Population_in_severe_multidimensional_poverty        0
# Contribution of depr (Health)                        0
# Contribution of depr (Education)                     0
# Contribution of depr (Standard of living)            0
# dtype: int64

# %%
data.describe()
# Out:
#             Index  Headcount_(%)  Intensity_of_deprivation  \
# count  105.000000     105.000000                105.000000
# mean     0.159234      30.578104                 45.827288
# std      0.161106      27.695810                  7.483873
# min      0.000675       0.186516                 34.234077
# 25%      0.017324       4.379236                 39.490393
# 50%      0.120762      27.505881                 45.187637
# 75%      0.262263      51.950502                 51.594973
# max      0.591433      91.915685                 65.289581
#
#        Number_of_poor_(year_of_survey)  Number_of_poor_2016  \
# count                       105.000000           105.000000
# mean                      12367.413337         12710.807676
# std                       38867.922349         38967.449419
# min                           2.399119             2.404938
# 25%                         264.211032           297.292206
# 50%                        2597.667548          2736.631592
# ...

# %%
data.dtypes
# Out:
# Country                                               object
# Year_survey                                           object
# Index                                                float64
# Headcount_(%)                                        float64
# Intensity_of_deprivation                             float64
# Number_of_poor_(year_of_survey)                      float64
# Number_of_poor_2016                                  float64
# Population_vulnerable_to_multidimensional_poverty    float64
# Population_in_severe_multidimensional_poverty        float64
# Contribution of depr (Health)                        float64
# Contribution of depr (Education)                     float64
# Contribution of depr (Standard of living)            float64
# dtype: object

# %%
data.describe()
# Out:
#             Index  Headcount_(%)  Intensity_of_deprivation  \
# count  105.000000     105.000000                105.000000
# mean     0.159234      30.578104                 45.827288
# std      0.161106      27.695810                  7.483873
# min      0.000675       0.186516                 34.234077
# 25%      0.017324       4.379236                 39.490393
# 50%      0.120762      27.505881                 45.187637
# 75%      0.262263      51.950502                 51.594973
# max      0.591433      91.915685                 65.289581
#
#        Number_of_poor_(year_of_survey)  Number_of_poor_2016  \
# count                       105.000000           105.000000
# mean                      12367.413337         12710.807676
# std                       38867.922349         38967.449419
# min                           2.399119             2.404938
# 25%                         264.211032           297.292206
# 50%                        2597.667548          2736.631592
# ...

# %%
print(data.sort_values(by ='Index',ascending=False).iloc[0])
print(data.sort_values(by ='Index',ascending=True).iloc[0])
# Out:
# Country                                                 Niger
# Year_survey                                            2012 D
# Index                                                0.591433
# Headcount_(%)                                         90.5861
# Intensity_of_deprivation                              65.2896
# Number_of_poor_(year_of_survey)                       16062.4
# Number_of_poor_2016                                   18726.8
# Population_vulnerable_to_multidimensional_poverty     4.99243
# Population_in_severe_multidimensional_poverty         74.8815
# Contribution of depr (Health)                         20.4043
# Contribution of depr (Education)                      37.2357
# Contribution of depr (Standard of living)               42.36
# Name: 0, dtype: object
# Country                                                  Armenia
# Year_survey                                          2015/2016 D
# Index                                                0.000675448
# ...

# %%
sns.pairplot(data)
